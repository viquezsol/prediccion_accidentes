# %%
import pandas as pd
import plotly.express as px
import json
import plotly.io as pio

# %%
path_csv = r'C:\Users\Cami\Downloads\Mapas2\Accidentes.csv'
path_json_coords = r'C:\Users\Cami\Downloads\Mapas2\cr.json'
df = pd.read_csv(path_csv, sep=';')
with open(path_json_coords, encoding='utf-8') as f:
    coords_data = json.load(f)

import plotly.express as px fig = px . density_map ( df , lat = 'Latitude' , lon = 'Longitude' , z = 'Magnitude' , radius = 10 , center = dict ( lat = 0 , lon = 180 ), zoom = 0 , map_style = "open-street-map" ) fig . show ()
# Out:
#   Cell In[2], line 7
#     import plotly.express as px fig = px . density_map ( df , lat = 'Latitude' , lon = 'Longitude' , z = 'Magnitude' , radius = 10 , center = dict ( lat = 0 , lon = 180 ), zoom = 0 , map_style = "open-street-map" ) fig . show ()
#                              ^
# SyntaxError: cannot use name as import target
